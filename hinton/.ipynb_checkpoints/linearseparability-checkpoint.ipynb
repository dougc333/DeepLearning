# %%
Linear separability Demo using Hinton's code as example. Converted from octave

# %%
a=

# %%
import numpy as np

#simple linear neuron. If less than activation, 0 if more 1. Binary class training. 
#the definiton of a perceptron is a linear neuron with a binary activation function
#
class perceptron:
    
    def __init__(self):
        self.x=0
        self.w_init=0
        self.w_neg=0
        self.w_pos=0
        self.neg = 0
        self.pos = 0
        
    def setExamples(self,n,p):
        self.neg=n
        self.pos=p
        
    def setX(self,input):
        self.x = input
    
    def setWeight(self,weight):
        self.w = weight
    
    def iterate(self):
        
        for i in range(len(self.neg)):
            print ('self.neg[i]:',self.neg[i],'type:',type(self.neg[i]))
            x = self.neg[i]
            print ('x.shape:',x.shape)
            print ('x.T shape:',x.T.shape)
            print ('self.w shape:', self.w.shape)
            activation = np.dot(x.T, self.w_init)
            print ('activation:', activation)
            if activation >= 0:
                print('activation > 0 updating weights')
                deltaw = x*(0-activation);
                self.w_neg = self.w_neg + deltaw;
                print('neg_examples deltaw:\t', deltaw, '\n');
                print('neg_examples after update w:\t', self.w, '\n');
        
        for i in range(len(self.pos)):
            print (self.pos[i])
            x = np.array(self.pos[i])
            print ('x.shape:',x.shape)
            print ('x.T shape:',x.T.shape)
            print ('self.w shape:', self.w.shape)
            activation = np.dot(x.T, self.w)
            print ('neg activation:', activation)
            if activation > 0:
                print('activation > 0 updating weights')
                deltaw = x*(1-activation);
                self.w = self.w + deltaw;
                print('pos_examples deltaw:\t', deltaw, '\n');
                print('pos_examples after update w:\t', self.w, '\n');
            
       
            
    
   
  

#tehre are 4 datasets here from hinton assignment1 coursera
            
pos_examples =[ np.array([[0.871429,0.624585,1]]),np.array([[ -0.020000,-0.923588,1]]),
                         np.array([[0.362857,-0.318937,1]]),np.array([[0.888571,-0.870432,1]])]

neg_examples = [np.array([[-0.80857,0.83721,1]]),
                np.array([[0.35714,0.85050,1]]),
                np.array([[-0.75143,-0.73090,1]]),
                np.array([[-0.30000,0.12625,1]])]

#dataset2
#pos_examples_nobias =
#
#   0.871429   0.624585
#  -0.020000  -0.923588
#   0.362857  -0.318937
#   0.888571  -0.870432
#  -0.528571   0.511628
#neg_examples_nobias =
#
#  -0.80857   0.83721
#   0.35714   0.85050
#  -0.75143  -0.73090
#  -0.30000   0.12625
#   0.64286  -0.54485


#pos_examples_nobias =
#
#  -0.76286  -0.19269
#  -0.60286  -0.48505
#  -0.38571  -0.69767
#  -0.19143  -0.35880
#   0.28286  -0.43189
#   0.40857  -0.69767
#   0.75143  -0.23256
#
#>> neg_examples_nobias
#neg_examples_nobias =
#
#  -0.791429   0.079734
#  -0.557143   0.411960
#  -0.225714   0.697674
#   0.162857   0.830565
#   0.460000   0.657807
#   0.734286   0.338870
#   0.825714  -0.013289

#pos_examples_nobias =
#
#  -0.0885714   0.2325581
#   0.0085714  -0.0664452
#   0.1285714  -0.3255814
#   0.2885714  -0.5249169
#   0.5971429  -0.4651163
#   0.7171429  -0.1461794
#  0.8600000   0.1594684
#   0.9457143   0.4451827

#>> neg_examples_nobias
#neg_examples_nobias =
#
#  -0.865714  -0.392027
#  -0.785714  -0.172757
#  -0.557143   0.245847
#  -0.288571   0.524917
#  -0.128571   0.524917
#   0.082857   0.332226
#  0.180000   0.106312
#   0.254286  -0.166113
#   0.328571  -0.352159





w_init = np.array([-0.62170,0.76092,0.77187])
print ('w_init shape:',w_init.shape)
perc  = perceptron()
perc.setExamples(neg_examples,pos_examples)
perc.setWeight(w_init)
perc.iterate()
# Out:
# w_init shape: (3,)
# self.neg[i]: [[-0.80857, 0.83721, 1]] type: <class 'list'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-cf37ae4d7ba3> in <module>()
#     142 perc.setExamples(neg_examples,pos_examples)
#     143 perc.setWeight(w_init)
# --> 144 perc.iterate()
#
# <ipython-input-10-cf37ae4d7ba3> in iterate(self)
#      29             print ('self.neg[i]:',self.neg[i],'type:',type(self.neg[i]))
#      30             x = self.neg[i]
# ---> 31             print ('x.shape:',x.shape)
#      32             print ('x.T shape:',x.T.shape)
#      33             print ('self.w shape:', self.w.shape)
#
# AttributeError: 'list' object has no attribute 'shape'
