# %%
# Load pickled data
import matplotlib.pyplot as plt
import pickle, cv2, csv, os, time
import numpy as np
from numpy import newaxis
from random import randint
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from matplotlib import gridspec
# %matplotlib inline
from keras.models import model_from_json
from keras.optimizers import Adam
import copy
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.optimizers import SGD, RMSprop
from keras.utils import np_utils
from keras.regularizers import l2
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D, AveragePooling2D
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from skimage.transform import rescale, resize, downscale_local_mean

from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
current_path = os.getcwd()
print (current_path)
train_path1 = current_path + "/train/Type_1/"
train_path2 = current_path + "/train/Type_2/"
train_path3 = current_path + "/train/Type_3/"
add_type1 = current_path + "/additional_Type_1_v2/Type_1/" 
add_type2 = current_path + "/additional_Type_2_v2/Type_2/" 
add_type3 = current_path + "/additional_Type_3_v2/Type_3/" 

test = current_path+"/test/"

path_list =[]
path_list.append(add_type1)
path_list.append(add_type2)
path_list.append(add_type3)
path_list.append(train_path1)
path_list.append(train_path2)
path_list.append(train_path3)

path_list.append(test)

 
def resize_images(path,pickle_filename):
    resize_img=[]
    size_dict= {}
    #for path in path_list:
    start_time = time.time()
    for root, dirs, files in os.walk(path, topdown=False):
        print ("path:",path,' numFiles:',len(files))
        for f in files:
            if f !='.DS_Store':
                print ("path:",path," path+f:",path+f)
                img = cv2.imread(path+f)
                print ("img shape:",img.shape)
                image_resize = resize(img, (32, 32), mode='reflect')
                print("img_resize shape:",image_resize.shape)
                resize_img.append(image_resize)
                print("size list:",len(resize_img))                
                size_dict[img.shape[0]]=img.shape[1]
        print("dict of image dimensions:",size_dict)
        with open(pickle_filename,'wb') as save_file:
            pickle.dump(resize_img,save_file)
    end_time = time.time()
    print("elapsed time:",(end_time-start_time)/60.)

#uncomment each one to run. Should run wo memory error. 
resize_images(train_path1,'type1_resize32.p')
#resize_images(train_path2,'type2resize32.p')
#resize_images(train_path3,'type3resize32.p')
#resize_images(add_type1,'type1addresize32.p')
#resize_images(add_type2,'type2addresize32.p')
#resize_images(add_type3,'type3addresize32.p')
#resize_images(test,'test.p')
# Out:
# /home/dc/DeepLearning/kaggle
# path: /home/dc/DeepLearning/kaggle/test/  numFiles: 512
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/397.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 1
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/163.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 2
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/72.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 3
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/496.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/482.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 5
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/425.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 6
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/344.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 7
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/29.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 8
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/241.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 9
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/258.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 10
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/467.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 11
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/324.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 12
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/415.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 13
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/47.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 14
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/352.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 15
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/471.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 16
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/107.jpg
# img shape: (640, 480, 3)
# img_resize shape: (224, 224, 3)
# size list: 17
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/56.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 18
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/95.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 19
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/268.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 20
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/11.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 21
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/346.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 22
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/448.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 23
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/435.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 24
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/285.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 25
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/423.jpg
# img shape: (2448, 3264, 3)
# img_resize shape: (224, 224, 3)
# size list: 26
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/274.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 451
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/243.jpg
# img shape: (3096, 4128, 3)
# img_resize shape: (224, 224, 3)
# size list: 452
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/110.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 453
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/69.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 454
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/261.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 455
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/307.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 456
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/81.jpg
# img shape: (2448, 3264, 3)
# img_resize shape: (224, 224, 3)
# size list: 457
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/436.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 458
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/256.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 459
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/212.jpg
# img shape: (4128, 2322, 3)
# img_resize shape: (224, 224, 3)
# size list: 460
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/267.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 461
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/237.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 462
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/209.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 463
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/151.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 464
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/506.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 465
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/430.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 466
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/400.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 467
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/466.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 468
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/362.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 469
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/413.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 470
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/469.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 471
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/336.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 472
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/358.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 473
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/141.jpg
# img shape: (640, 480, 3)
# img_resize shape: (224, 224, 3)
# size list: 474
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/338.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 475
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/315.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 476
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/221.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 477
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/404.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 478
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/8.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 479
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/23.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 480
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/385.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 481
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/236.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 482
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/79.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 483
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/9.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 484
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/147.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 485
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/348.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 486
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/71.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 487
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/318.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 488
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/282.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 489
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/406.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 490
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/97.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 491
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/459.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 492
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/70.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 493
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/218.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 494
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/428.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 495
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/433.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 496
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/130.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 497
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/280.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 498
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/446.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 499
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/347.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 500
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/17.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 501
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/46.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 502
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/2.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 503
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/325.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 504
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/44.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 505
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/126.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 506
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/50.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 507
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/453.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 508
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/326.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 509
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/349.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 510
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/120.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 511
# path: /home/dc/DeepLearning/kaggle/test/  path+f: /home/dc/DeepLearning/kaggle/test/170.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 512
# dict of image dimensions: {4128: 3096, 3264: 2448, 2448: 3264, 3096: 4128, 4160: 3120, 640: 480}
# elapsed time: 6.316843724250793

# %%
img1 = []
read_file = open('type1_resize.p', 'rb') 
imgs_type1 = pickle.load( read_file)
img1 += imgs_type1
print("num type1 images(250):", len(imgs_type1)) #should be 250

read_file = open('type1add_resize.p', 'rb') 
imgs_type1 = pickle.load( read_file)
img1 += imgs_type1
print('num type1 additional images(1190):',len(imgs_type1))


print(len(img1))
label_1 = [0]*(len(img1))
print ('sample label for class Type1 should be 0:',label_1[0])
print ('num labels_1:',len(label_1))
# Out:
# num type1 images(250): 250
# num type1 additional images(1190): 1190
# 1440
# sample label for class Type1 should be 0: 0
# num labels_1: 1440

# %%
read_file = open('test.p','rb')
imgs_test = pickle.load(read_file)
print(len(imgs_test))
# Out:
# 512

# %%
path = '/Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/'
path_first='/Users/dc/DeepLearning/kaggle/first1k/'
path_second='/Users/dc/DeepLearning/kaggle/2ndk/'
path_third='/Users/dc/DeepLearning/kaggle/3rdk/'
num=0
for root, dirs, files in os.walk(path):
    for file in files:
        print('moving:',file)
        if (file != '.DS_Store'):
            if (num < 1000):
                os.rename(path+file,path_first+file)
            elif ((num>1000) and (num<2000)):
                os.rename(path+file,path_second+file)
            else:
                os.rename(path+file,path_third+file)
            num+=1
    print('num:',num)

# %%
path_first='/Users/dc/DeepLearning/kaggle/first1k/'
path_second='/Users/dc/DeepLearning/kaggle/2ndk/'
path_third='/Users/dc/DeepLearning/kaggle/3rdk/'

resize_images(path_first,'type2_first.p')
resize_images(path_second,'type2_second.p')
resize_images(path_third,'type2_third.p')

# %%
#redo type 2. Too many files for stupid pickle format

path = '/Users/dc/DeepLearning/kaggle/additional_Type_2_v2'
first1k=[]
second1k=[]
third1k=[]
for file in os.walk(path):
    print (file)
    img = cv2.imread(path+file)
    image_resize = resize(img, (224, 224), mode='reflect')
    if (num < 1000) and (file!='.DS_Store'):
        first1k.append(image_resize)
    else if ((num>1000) and (num<2000)):
        second1k.append(image_resize)
    else:
        thirdk.append(image_resize)
    num+=1

# %%
#redo type2

img2 = []

read_file = open('type2resize.p', 'rb') 
imgs_type2 = pickle.load( read_file)
img2 += imgs_type2
print("num type2_resize:", len(imgs_type2)) #should be 1000-1 for DS_Store


read_file = open('type2_first.p', 'rb') 
imgs_type2 = pickle.load( read_file)
img2 += imgs_type2
print("num type2_first:", len(imgs_type2)) #should be 1000

read_file = open('type2_second.p', 'rb') 
imgs_type2 = pickle.load( read_file)
img2 += imgs_type2
print("num type2_second:", len(imgs_type2)) #should be 999

read_file = open('type2_third.p', 'rb') 
imgs_type2 = pickle.load( read_file)
img2 += imgs_type2
print("num type2_third:", len(imgs_type2)) #should be 1566


label_2=[1]*(781+1000+999+1566)
print ('label_2:',len(label_2))
print ('sample label for Type2 should be 1:',label_2[0])
print ('num img2:',len(img2))
# Out:
# num type2_resize: 781
# num type2_first: 1000
# num type2_second: 999
# num type2_third: 1566
# label_2: 4346
# sample label for Type2 should be 1: 1
# num img2: 4346

# %%
# redo type3 move type3 files
path = '/Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/'
path_first='/Users/dc/DeepLearning/kaggle/first_third1k/'
path_second='/Users/dc/DeepLearning/kaggle/third2ndk/'
#path_third='/Users/dc/DeepLearning/kaggle/third3rdk/'

num = 0

for root, dirs, files in os.walk(path):
    for file in files:
        print('moving:',file)
        if (file != '.DS_Store'):
            if (num < 1000):
                os.rename(path+file,path_first+file)
            elif ((num>1000) and (num<2000)):
                os.rename(path+file,path_second+file)
            else:
                os.rename(path+file,path_third+file)
            num+=1
    print('num:',num)

# %%
path_first='/Users/dc/DeepLearning/kaggle/first_third1k/'
path_second='/Users/dc/DeepLearning/kaggle/third2ndk/'
#path_third='/Users/dc/DeepLearning/kaggle/3rdk/'

resize_images(path_first,'type3_first.p')
resize_images(path_second,'type3_second.p')

# %%
img3=[]

read_file = open('type3resize.p', 'rb') 
imgs_type3 = pickle.load( read_file)
img3 += imgs_type3
print("num type3_resize:", len(imgs_type3)) #should be 


read_file = open('type3_first.p', 'rb') 
imgs_type3 = pickle.load( read_file)
img3 += imgs_type3
print("num type3_first:", len(imgs_type3)) #should be 1000

read_file = open('type3_second.p', 'rb') 
imgs_type3 = pickle.load( read_file)
img3 += imgs_type3
print("num type3_second:", len(imgs_type3)) #should be 975


print('num img3:',len(img3))
label_3 = [2]*(450+1000+975)
print ('len label_3:', len(label_3))
print ('sample label for Type3, should be 2:',label_3[0])

#convert after you mix them up and shuffle
#label_3add = np_utils.to_categorical(label_3add, 3)
# Out:
# num type3_resize: 450
# num type3_first: 1000
# num type3_second: 975
# num img3: 2425
# len label_3: 2425
# sample label for Type3, should be 2: 2

# %%
#error check
img = img1+img2+img3
label=label_1+label_2+label_3

#save these to verify the labels match the images
with open('img.p','wb') as save_file:
    pickle.dump(img,save_file)
with open('label.p','wb') as save_file:
    pickle.dump(label,save_file)

print(len(img), len(label))
print(type(img),type(label))
X_train = np.array(img)
y_train = np_utils.to_categorical(label, 3)
print(X_train.shape, y_train.shape)
#change to 25% then split test to test and valid. 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_train,y_train, test_size=.25, random_state=42)
X_test2,ytest2,Xvalid2,yvalid2 = train_test_split(X_test1,y_test2,test_size=.5,random_state=42)

#normalize
# Out:
# 8211 8211
# <class 'list'> <class 'list'>
# (8211, 224, 224, 3) (8211, 3)

# %%
X_test = np.array(imgs_test)

# %%
print(X_test.shape)
# Out:
# (512, 224, 224, 3)

# %%
asdf=np_utils.to_categorical(y_train,3)
asdf[0]
# Out:
# array([ 0.,  1.,  0.])

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator


print (K.image_data_format())

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=( 150, 150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
# Out:
# channels_last

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
import os,random


def move_file(source_path,dest_path):
    """
    input: source path, dest path
    output: move 20 percent files from source path to dest path
    """
    list_files = os.listdir(source_path)
    print (len(list_files))

    num_moved=0
    for x in range(1,int(.20*len(list_files))):
        index = random.randint(1, len(list_files))
        print(index,list_files[index])
        source_file = source_path+list_files[index]
        if(os.path.isfile(source_file)):
            dest_file = dest_path+list_files[index]
            os.rename(source_file,dest_file)
            num_moved+=1

    print (num_moved)

#move_file(os.getcwd()+"/data/train/type1/",os.getcwd()+"/data/valid/type1/")
#move_file(os.getcwd()+"/data/train/type2/",os.getcwd()+"/data/valid/type2/")
move_file(os.getcwd()+"/data/train/type3/",os.getcwd()+"/data/valid/type3/")

# %%
import os
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Convolution2D,MaxPooling2D,Flatten
from keras.optimizers import Adam


# number of classes
nb_classes = 3

# input image dimensions
img_rows, img_cols,img_ch = 224, 224, 3

# number of convolutional filters to use
nb_filter1 = 32
nb_filter2 = 64
nb_filter3 = 128



model = Sequential()
model.add(Convolution2D(32, kernel_size=(3, 3),padding='same',
                        input_shape=(img_rows,img_cols,img_ch),name='conv1'))
model.add(Activation('relu',name='relu1'))
model.add(MaxPooling2D(pool_size=(2,2),strides=1,name='maxpool1'))
model.add(Convolution2D(64, kernel_size=(3, 3),padding='same',
                        name='conv2'))
model.add(Activation('relu',name='relu2'))
model.add(MaxPooling2D(pool_size=(2,2),strides=None,name='maxpool2'))
model.add(Convolution2D(128, kernel_size=(3, 3), padding='same',
                        name='conv3'))
model.add(Activation('relu',name='relu3'))
model.add(MaxPooling2D(pool_size=(2,2),strides=None,name='maxpool3'))
model.add(Flatten(name='flatten'))
model.add(Dropout(0.5,name='dropout1'))
model.add(Dense(128, name='hidden1'))
model.add(Activation('relu',name='relu4'))
model.add(Dropout(0.5,name='dropout2'))
model.add(Dense(128,  name='hidden2'))
model.add(Activation('relu',name='relu5'))
model.add(Dense(nb_classes, name='output'))
model.add(Activation('softmax',name='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 224, 224, 32)      896
# _________________________________________________________________
# relu1 (Activation)           (None, 224, 224, 32)      0
# _________________________________________________________________
# maxpool1 (MaxPooling2D)      (None, 223, 223, 32)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 223, 223, 64)      18496
# _________________________________________________________________
# relu2 (Activation)           (None, 223, 223, 64)      0
# _________________________________________________________________
# maxpool2 (MaxPooling2D)      (None, 111, 111, 64)      0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 111, 111, 128)     73856
# _________________________________________________________________
# relu3 (Activation)           (None, 111, 111, 128)     0
# _________________________________________________________________
# maxpool3 (MaxPooling2D)      (None, 55, 55, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 387200)            0
# _________________________________________________________________
# dropout1 (Dropout)           (None, 387200)            0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               49561728
# _________________________________________________________________
# relu4 (Activation)           (None, 128)               0
# _________________________________________________________________
# dropout2 (Dropout)           (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# relu5 (Activation)           (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 3)                 387
# _________________________________________________________________
# softmax (Activation)         (None, 3)                 0
# =================================================================
# Total params: 49,671,875
# Trainable params: 49,671,875
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
nb_epoch = 200
batch_size=50

model_name='test.chkpt'

if os.path.isfile(model_name):
    try:
        model = load_model(model_name)
        print('loading trained model ...')
    except Exception as e:
        print('Unable to load model', model_name, ':', e)
        raise    


adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

startTime = time.time()
history = model.fit(X_train1, y_train1,
                    batch_size=batch_size, epochs=nb_epoch,
                    verbose=2, validation_data=(X_test1, y_test1))

endTime = time.time()
print('elapsed secs:', (endTime - startTime)/1000.)
#nvidia-smi to see power stats nvidia-smi -i 3 -l -q -d
# Out:
# Train on 6568 samples, validate on 1643 samples
# Epoch 1/200
# 52s - loss: 1.0027 - acc: 0.5228 - val_loss: 0.9826 - val_acc: 0.5204
# Epoch 2/200
# 45s - loss: 0.9677 - acc: 0.5344 - val_loss: 0.9626 - val_acc: 0.5356
# Epoch 3/200
# 45s - loss: 0.9429 - acc: 0.5445 - val_loss: 0.9527 - val_acc: 0.5350
# Epoch 4/200
# 46s - loss: 0.9226 - acc: 0.5513 - val_loss: 0.9193 - val_acc: 0.5563
# Epoch 5/200
# 46s - loss: 0.8891 - acc: 0.5690 - val_loss: 0.9050 - val_acc: 0.5624
# Epoch 6/200
# 46s - loss: 0.8601 - acc: 0.5901 - val_loss: 0.8937 - val_acc: 0.5624
# Epoch 7/200
# 46s - loss: 0.8310 - acc: 0.5968 - val_loss: 0.8838 - val_acc: 0.5703
# Epoch 8/200
# 50s - loss: 0.7958 - acc: 0.6128 - val_loss: 0.8616 - val_acc: 0.5922
# 46s - loss: 0.0287 - acc: 0.9895 - val_loss: 2.8933 - val_acc: 0.6372
# Epoch 191/200
# 47s - loss: 0.0270 - acc: 0.9910 - val_loss: 2.8807 - val_acc: 0.6318
# Epoch 192/200
# 47s - loss: 0.0340 - acc: 0.9884 - val_loss: 2.9002 - val_acc: 0.6324
# Epoch 193/200
# 47s - loss: 0.0251 - acc: 0.9910 - val_loss: 3.0426 - val_acc: 0.6293
# Epoch 194/200
# 47s - loss: 0.0181 - acc: 0.9938 - val_loss: 3.0166 - val_acc: 0.6360
# Epoch 195/200
# 47s - loss: 0.0278 - acc: 0.9895 - val_loss: 2.7858 - val_acc: 0.6336
# Epoch 196/200
# 47s - loss: 0.0265 - acc: 0.9890 - val_loss: 2.8557 - val_acc: 0.6299
# Epoch 197/200
# 47s - loss: 0.0249 - acc: 0.9912 - val_loss: 2.6812 - val_acc: 0.6239
# Epoch 198/200
# 47s - loss: 0.0221 - acc: 0.9913 - val_loss: 2.9782 - val_acc: 0.6269
# Epoch 199/200
# 47s - loss: 0.0280 - acc: 0.9892 - val_loss: 2.6682 - val_acc: 0.6366
# Epoch 200/200
# 47s - loss: 0.0262 - acc: 0.9898 - val_loss: 2.9707 - val_acc: 0.6415
# elapsed secs: 9.458678702116012

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
loaded_model.summary()
# Out:
# Loaded model from disk
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 224, 224, 32)      896
# _________________________________________________________________
# relu1 (Activation)           (None, 224, 224, 32)      0
# _________________________________________________________________
# maxpool1 (MaxPooling2D)      (None, 223, 223, 32)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 223, 223, 64)      18496
# _________________________________________________________________
# relu2 (Activation)           (None, 223, 223, 64)      0
# _________________________________________________________________
# maxpool2 (MaxPooling2D)      (None, 111, 111, 64)      0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 111, 111, 128)     73856
# _________________________________________________________________
# relu3 (Activation)           (None, 111, 111, 128)     0
# _________________________________________________________________
# maxpool3 (MaxPooling2D)      (None, 55, 55, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 387200)            0
# _________________________________________________________________
# dropout1 (Dropout)           (None, 387200)            0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               49561728
# _________________________________________________________________
# relu4 (Activation)           (None, 128)               0
# _________________________________________________________________
# dropout2 (Dropout)           (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# relu5 (Activation)           (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 3)                 387
# _________________________________________________________________
# softmax (Activation)         (None, 3)                 0
# =================================================================
# Total params: 49,671,875
# Trainable params: 49,671,875
# Non-trainable params: 0
# _________________________________________________________________

# %%
#this doesnt work to reset
from keras import backend as K

def limit_mem():
    K.get_session().close()
    cfg = K.tf.ConfigProto()
    cfg.gpu_options.allow_growth = True
    K.set_session(K.tf.Session(config=cfg))

limit_mem()

# %%
predict = loaded_model.predict(X_test)

# %%
predict[0]
# Out:
# array([  1.00749046e-13,   1.00000000e+00,   2.02010197e-11], dtype=float32)
