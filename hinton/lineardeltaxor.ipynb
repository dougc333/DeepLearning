# %%
import numpy  as np

class linear_xor(object):
    def __init__(self,in1,in2,w1,w2, out, learning_rate):
        self.in1 = in1
        self.in2 = in2
        self.output_nodes = out
        self.learning_rate = learning_rate
        self.w1=w1
        self.w2=w2
        
    def y_output(self,x,w):
        out1 = x[0]*w[0]
        out2 = x[1]*w[1]
        out = out1+out2
        return out
    
    def train(self):
        t=[0,0,1,1]
        x=[[0,0],[0,1],[1,0],[1,1]]
        w=[0,0]
    
        for x1 in range(10):
            for i in range(len(t)):
                deltaw = self.learning_rate*(t[i]-self.y_output(x[i],w))
                print ('deltaw:', deltaw," w:",w)
                w[0] +=deltaw
                w[1] +=deltaw

lxor = linear_xor(0,0,0,0,0,0.1)
lxor.train()
# Out:
# deltaw: 0.0  w: [0, 0]
# deltaw: 0.0  w: [0.0, 0.0]
# deltaw: 0.1  w: [0.0, 0.0]
# deltaw: 0.08000000000000002  w: [0.1, 0.1]
# deltaw: 0.0  w: [0.18000000000000002, 0.18000000000000002]
# deltaw: -0.018000000000000002  w: [0.18000000000000002, 0.18000000000000002]
# deltaw: 0.0838  w: [0.16200000000000003, 0.16200000000000003]
# deltaw: 0.050839999999999996  w: [0.24580000000000002, 0.24580000000000002]
# deltaw: 0.0  w: [0.29664, 0.29664]
# deltaw: -0.029664000000000003  w: [0.29664, 0.29664]
# deltaw: 0.0733024  w: [0.266976, 0.266976]
# deltaw: 0.031944320000000005  w: [0.3402784, 0.3402784]
# deltaw: 0.0  w: [0.37222272, 0.37222272]
# deltaw: -0.037222272  w: [0.37222272, 0.37222272]
# deltaw: 0.0664999552  w: [0.335000448, 0.335000448]
# deltaw: 0.01969991936  w: [0.4015004032, 0.4015004032]
# deltaw: 0.0  w: [0.42120032256, 0.42120032256]
# deltaw: -0.042120032256  w: [0.42120032256, 0.42120032256]
# deltaw: 0.0620919709696  w: [0.37908029030400003, 0.37908029030400003]
# ...
