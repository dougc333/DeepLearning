# %%
# Load pickled data
import matplotlib.pyplot as plt
import pickle, cv2, csv, os, time
import numpy as np
from numpy import newaxis
from random import randint
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from matplotlib import gridspec
# %matplotlib inline
from keras.models import model_from_json
from keras.optimizers import Adam
import copy
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.optimizers import SGD, RMSprop
from keras.utils import np_utils
from keras.regularizers import l2
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D, AveragePooling2D
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization
from skimage.transform import rescale, resize, downscale_local_mean

from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
#for cleanup copying dir to another by accident. copied files from additionalType2 to additionalType1
num_dup=0
for root, dirs, files in os.walk('first1k/', topdown=False):
    for f in files:
        if(os.path.isfile('additional_Type_1_v2//Type_1/'+f)):
            print ('file exists in another dir!!!',f)
            os.remove('additional_Type_1_v2/Type_1/'+f)
            num_dup+=1
print (num_dup)
# Out:
# 0

# %%
current_path = os.getcwd()
print (current_path)
train_path1 = current_path + "/train/Type_1/"
train_path2 = current_path + "/train/Type_2/"
train_path3 = current_path + "/train/Type_3/"
add_type1 = current_path + "/additional_Type_1_v2/Type_1/" 
add_type2 = current_path + "/additional_Type_2_v2/Type_2/" 
add_type3 = current_path + "/additional_Type_3_v2/Type_3/" 

test = current_path+"/test/"

path_list =[]
path_list.append(add_type1)
path_list.append(add_type2)
path_list.append(add_type3)
path_list.append(train_path1)
path_list.append(train_path2)
path_list.append(train_path3)

path_list.append(test)

 
def resize_images(path,pickle_filename):
    resize_img=[]
    size_dict= {}
    #for path in path_list:
    start_time = time.time()
    for root, dirs, files in os.walk(path, topdown=False):
        print ("path:",path,' numFiles:',len(files))
        for f in files:
            if f !='.DS_Store':
                print ("path:",path," path+f:",path+f)
                img = cv2.imread(path+f)
                print ("img shape:",img.shape)
                image_resize = resize(img, (32, 32), mode='reflect')
                print("img_resize shape:",image_resize.shape)
                resize_img.append(image_resize)
                print("size list:",len(resize_img))                
                size_dict[img.shape[0]]=img.shape[1]
        print("dict of image dimensions:",size_dict)
        with open(pickle_filename,'wb') as save_file:
            pickle.dump(resize_img,save_file)
    end_time = time.time()
    print("elapsed time:",(end_time-start_time)/60.)

#uncomment each one to run. Should run wo memory error. 
#resize_images(train_path1,'type1_resize32.p')
#resize_images(train_path2,'type2resize32.p')
#resize_images(train_path3,'type3resize32.p')
#resize_images(add_type1,'type1addresize32.p')
#resize_images(add_type2,'type2addresize32.p')
resize_images(add_type3,'type3addresize32.p')
#resize_images(test,'test.p')
# Out:
# /Users/dc/DeepLearning/kaggle
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  numFiles: 1975
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/100.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/1010.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (32, 32, 3)
# size list: 2
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/1012.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 3
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/1014.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 4
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/1019.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 5
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/1021.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 6
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/1027.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list:
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/771.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1921
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/773.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1922
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/774.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1923
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/779.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1924
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/78.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1925
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/785.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1926
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/792.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1927
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/793.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1928
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/8.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1929
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/806.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1930
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/81.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1931
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/812.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1932
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/814.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1933
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/818.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1934
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/82.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1935
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/825.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1936
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/838.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1937
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/844.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (32, 32, 3)
# size list: 1938
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/850.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1939
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/851.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1940
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/854.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1941
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/857.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1942
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/858.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1943
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/865.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1944
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/876.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1945
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/877.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1946
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/881.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1947
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/885.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1948
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/889.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1949
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/89.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1950
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/890.jpg
# img shape: (640, 480, 3)
# img_resize shape: (32, 32, 3)
# size list: 1951
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/892.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1952
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/893.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1953
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/899.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1954
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/909.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1955
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/910.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1956
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/911.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1957
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/914.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1958
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/918.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1959
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/924.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1960
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/925.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1961
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/926.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1962
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/927.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1963
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/928.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1964
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/945.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1965
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/95.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1966
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/954.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1967
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/965.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1968
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/966.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1969
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/97.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1970
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/977.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1971
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/983.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1972
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/984.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1973
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/992.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (32, 32, 3)
# size list: 1974
# path: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/996.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (32, 32, 3)
# size list: 1975
# dict of image dimensions: {3264: 2448, 4160: 3120, 2448: 3264, 4128: 3096, 3096: 4128, 640: 480}
# elapsed time: 24.44655238389969

# %%
img1 = []
read_file = open('type1_resize32.p', 'rb') 
imgs_type1 = pickle.load( read_file)
img1 += imgs_type1
print("num type1 images(250):", len(imgs_type1)) #should be 250

read_file = open('type1addresize32.p', 'rb') 
imgs_type1 = pickle.load( read_file)
img1 += imgs_type1
print('num type1 additional images(1190):',len(imgs_type1))


print(len(img1))
label_1 = [0]*(len(img1))
print ('sample label for class Type1 should be 0:',label_1[0])
print ('num labels_1:',len(label_1))
# Out:
# num type1 images(250): 250
# num type1 additional images(1190): 1190
# 1440
# sample label for class Type1 should be 0: 0
# num labels_1: 1440

# %%
read_file = open('test.p','rb')
imgs_test = pickle.load(read_file)
print(len(imgs_test))
# Out:
# 512

# %%
path = '/Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/'
path_first='/Users/dc/DeepLearning/kaggle/first1k/'
path_second='/Users/dc/DeepLearning/kaggle/2ndk/'
path_third='/Users/dc/DeepLearning/kaggle/3rdk/'
num=0
for root, dirs, files in os.walk(path):
    for file in files:
        print('moving:',file)
        if (file != '.DS_Store'):
            if (num < 1000):
                os.rename(path+file,path_first+file)
            elif ((num>1000) and (num<2000)):
                os.rename(path+file,path_second+file)
            else:
                os.rename(path+file,path_third+file)
            num+=1
    print('num:',num)

# %%
path_first='/Users/dc/DeepLearning/kaggle/first1k/'
path_second='/Users/dc/DeepLearning/kaggle/2ndk/'
path_third='/Users/dc/DeepLearning/kaggle/3rdk/'

resize_images(path_first,'type2_first.p')
resize_images(path_second,'type2_second.p')
resize_images(path_third,'type2_third.p')

# %%
#redo type 2. Too many files for stupid pickle format

path = '/Users/dc/DeepLearning/kaggle/additional_Type_2_v2'
first1k=[]
second1k=[]
third1k=[]
for file in os.walk(path):
    print (file)
    img = cv2.imread(path+file)
    image_resize = resize(img, (224, 224), mode='reflect')
    if (num < 1000) and (file!='.DS_Store'):
        first1k.append(image_resize)
    else if ((num>1000) and (num<2000)):
        second1k.append(image_resize)
    else:
        thirdk.append(image_resize)
    num+=1

# %%
#redo type2

img2 = []

read_file = open('type2resize32.p', 'rb') 
imgs_type2 = pickle.load( read_file)
img2 += imgs_type2
print("num type2_resize:", len(imgs_type2)) #should be 1000-1 for DS_Store

read_file = open('type2addresize32.p', 'rb') 
imgs_type2 = pickle.load( read_file)
img2 += imgs_type2
print("num type2addresize32:", len(imgs_type2)) #should be 1000-1 for DS_Store


#read_file = open('type2_first.p', 'rb') 
#imgs_type2 = pickle.load( read_file)
#img2 += imgs_type2
#print("num type2_first:", len(imgs_type2)) #should be 1000

#read_file = open('type2_second.p', 'rb') 
#imgs_type2 = pickle.load( read_file)
#img2 += imgs_type2
#print("num type2_second:", len(imgs_type2)) #should be 999

#read_file = open('type2_third.p', 'rb') 
#imgs_type2 = pickle.load( read_file)
#img2 += imgs_type2
#print("num type2_third:", len(imgs_type2)) #should be 1566


#label_2=[1]*(781+1000+999+1566)
label_2 = [1]*(len(img2))
print ('label_2:',len(label_2))
print ('sample label for Type2 should be 1:',label_2[0])
print ('num img2:',len(img2))
# Out:
# num type2_resize: 781
# num type2addresize32: 3566
# label_2: 4347
# sample label for Type2 should be 1: 1
# num img2: 4347

# %%
# redo type3 move type3 files
path = '/Users/dc/DeepLearning/kaggle/additional_Type_3_v2/Type_3/'
path_first='/Users/dc/DeepLearning/kaggle/first_third1k/'
path_second='/Users/dc/DeepLearning/kaggle/third2ndk/'
#path_third='/Users/dc/DeepLearning/kaggle/third3rdk/'

num = 0

for root, dirs, files in os.walk(path):
    for file in files:
        print('moving:',file)
        if (file != '.DS_Store'):
            if (num < 1000):
                os.rename(path+file,path_first+file)
            elif ((num>1000) and (num<2000)):
                os.rename(path+file,path_second+file)
            else:
                os.rename(path+file,path_third+file)
            num+=1
    print('num:',num)

# %%
path_first='/Users/dc/DeepLearning/kaggle/first_third1k/'
path_second='/Users/dc/DeepLearning/kaggle/third2ndk/'
#path_third='/Users/dc/DeepLearning/kaggle/3rdk/'

resize_images(path_first,'type3_first.p')
resize_images(path_second,'type3_second.p')

# %%
img3=[]

read_file = open('type3resize32.p', 'rb') 
imgs_type3 = pickle.load( read_file)
img3 += imgs_type3
print("num type3_resize:", len(imgs_type3)) #should be 

read_file = open('type3addresize32.p', 'rb') 
imgs_type3 = pickle.load( read_file)
img3 += imgs_type3
print("num type3_resize:", len(imgs_type3)) #should be 


#read_file = open('type3_first.p', 'rb') 
#imgs_type3 = pickle.load( read_file)
#img3 += imgs_type3
#print("num type3_first:", len(imgs_type3)) #should be 1000

#read_file = open('type3_second.p', 'rb') 
#imgs_type3 = pickle.load( read_file)
#img3 += imgs_type3
#print("num type3_second:", len(imgs_type3)) #should be 975


print('num img3:',len(img3))
#label_3 = [2]*(450+1000+975)
label_3 = [2]*(len(img3))
print ('len label_3:', len(label_3))
print ('sample label for Type3, should be 2:',label_3[0])

#convert after you mix them up and shuffle
#label_3add = np_utils.to_categorical(label_3add, 3)
# Out:
# num type3_resize: 450
# num type3_resize: 1975
# num img3: 2425
# len label_3: 2425
# sample label for Type3, should be 2: 2

# %%
#error check
img = img1+img2+img3
label=label_1+label_2+label_3

#save these to verify the labels match the images
with open('img.p','wb') as save_file:
    pickle.dump(img,save_file)
with open('label.p','wb') as save_file:
    pickle.dump(label,save_file)

print(len(img), len(label))
print(type(img),type(label))
X_train = np.array(img)
y_train = np_utils.to_categorical(label, 3)
X_train,y_train=shuffle(X_train,y_train)
print(X_train.shape, y_train.shape)
#change to 25% then split test to test and valid. 
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_train,y_train, test_size=.20, random_state=42)
#X_test2,ytest2,Xvalid2,yvalid2 = train_test_split(X_test1,y_test1,test_size=.5,random_state=42)

#normalize
# Out:
# 8212 8212
# <class 'list'> <class 'list'>
# (8212, 32, 32, 3) (8212, 3)

# %%
print(X_train[0])
# Out:
# [[[ 0.5754902   0.57990196  0.825     ]
#   [ 0.60784314  0.52058824  0.86568627]
#   [ 0.63186275  0.49264706  0.86127451]
#   ...,
#   [ 0.71372549  0.78578431  0.99068627]
#   [ 0.91372549  0.99705882  0.98823529]
#   [ 0.78431373  1.          0.96470588]]
#
#  [[ 0.50441176  0.36911765  0.83578431]
#   [ 0.48970588  0.39558824  0.83872549]
#   [ 0.55882353  0.44117647  0.85784314]
#   ...,
#   [ 0.72598039  0.56323529  0.92696078]
#   [ 0.64313725  0.50980392  0.88235294]
#   [ 0.60196078  0.65098039  0.95098039]]
#
#  [[ 0.28333333  0.15686275  0.81470588]
#   [ 0.32107843  0.24852941  0.82696078]
#   [ 0.45980392  0.34215686  0.84803922]
#   ...,
#   [ 0.70637255  0.5495098   0.92205882]
#   [ 0.5995098   0.41911765  0.85833333]
#   [ 0.52598039  0.38382353  0.82107843]]
#
#  ...,
#  [[ 0.45735294  0.40735294  0.85686275]
#   [ 0.46519608  0.3745098   0.73627451]
#   [ 0.53088235  0.47598039  0.75833333]
#   ...,
#   [ 0.4745098   0.36372549  0.78333333]
#   [ 0.48578431  0.36813725  0.77205882]
#   [ 0.47794118  0.36029412  0.77990196]]
#
#  [[ 0.47254902  0.41470588  0.94901961]
#   [ 0.40147059  0.34411765  0.76372549]
#   [ 0.47107843  0.41862745  0.74705882]
#   ...,
#   [ 0.4622549   0.32892157  0.72107843]
#   [ 0.44607843  0.31666667  0.72794118]
#   [ 0.38431373  0.27401961  0.7       ]]
#
#  [[ 0.46421569  0.42647059  0.99803922]
#   [ 0.42107843  0.34460784  0.83676471]
#   [ 0.42205882  0.37205882  0.72598039]
#   ...,
#   [ 0.39215686  0.27598039  0.68039216]
#   [ 0.37058824  0.25686275  0.68431373]
#   [ 0.29362745  0.21519608  0.63480392]]]

# %%
X_test = np.array(imgs_test)

# %%
print(X_test.shape)
# Out:
# (512, 224, 224, 3)

# %%
asdf=np_utils.to_categorical(y_train,3)
asdf[0]
# Out:
# array([ 0.,  1.,  0.])

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator


print (K.image_data_format())

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=( 150, 150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
# Out:
# channels_last

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
import os,random


def move_file(source_path,dest_path):
    """
    input: source path, dest path
    output: move 20 percent files from source path to dest path
    """
    list_files = os.listdir(source_path)
    print (len(list_files))

    num_moved=0
    for x in range(1,int(.20*len(list_files))):
        index = random.randint(1, len(list_files))
        print(index,list_files[index])
        source_file = source_path+list_files[index]
        if(os.path.isfile(source_file)):
            dest_file = dest_path+list_files[index]
            os.rename(source_file,dest_file)
            num_moved+=1

    print (num_moved)

#move_file(os.getcwd()+"/data/train/type1/",os.getcwd()+"/data/valid/type1/")
#move_file(os.getcwd()+"/data/train/type2/",os.getcwd()+"/data/valid/type2/")
move_file(os.getcwd()+"/data/train/type3/",os.getcwd()+"/data/valid/type3/")

# %%
import os
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Convolution2D,MaxPooling2D,Flatten
from keras.optimizers import Adam


# number of classes
nb_classes = 3

# input image dimensions
img_rows, img_cols,img_ch = 32, 32, 3

# number of convolutional filters to use
nb_filter1 = 32
nb_filter2 = 64
nb_filter3 = 128



model = Sequential()
model.add(Convolution2D(32, kernel_size=(3, 3),padding='same',
                        input_shape=(img_rows,img_cols,img_ch),name='conv1'))
model.add(Activation('relu',name='relu1'))
model.add(MaxPooling2D(pool_size=(2,2),strides=1,name='maxpool1'))
model.add(Convolution2D(64, kernel_size=(3, 3),padding='same',
                        name='conv2'))
model.add(Activation('relu',name='relu2'))
model.add(MaxPooling2D(pool_size=(2,2),strides=None,name='maxpool2'))
model.add(Convolution2D(128, kernel_size=(3, 3), padding='same',
                        name='conv3'))
model.add(Activation('relu',name='relu3'))
model.add(MaxPooling2D(pool_size=(2,2),strides=None,name='maxpool3'))
model.add(Flatten(name='flatten'))
model.add(Dropout(0.5,name='dropout1'))
model.add(Dense(128, name='hidden1'))
model.add(Activation('relu',name='relu4'))
model.add(Dropout(0.5,name='dropout2'))
model.add(Dense(128,  name='hidden2'))
model.add(Activation('relu',name='relu5'))
model.add(Dense(nb_classes, name='output'))
model.add(Activation('softmax',name='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 32, 32, 32)        896
# _________________________________________________________________
# relu1 (Activation)           (None, 32, 32, 32)        0
# _________________________________________________________________
# maxpool1 (MaxPooling2D)      (None, 31, 31, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 31, 31, 64)        18496
# _________________________________________________________________
# relu2 (Activation)           (None, 31, 31, 64)        0
# _________________________________________________________________
# maxpool2 (MaxPooling2D)      (None, 15, 15, 64)        0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 15, 15, 128)       73856
# _________________________________________________________________
# relu3 (Activation)           (None, 15, 15, 128)       0
# _________________________________________________________________
# maxpool3 (MaxPooling2D)      (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dropout1 (Dropout)           (None, 6272)              0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               802944
# _________________________________________________________________
# relu4 (Activation)           (None, 128)               0
# _________________________________________________________________
# dropout2 (Dropout)           (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# relu5 (Activation)           (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 3)                 387
# _________________________________________________________________
# softmax (Activation)         (None, 3)                 0
# =================================================================
# Total params: 913,091
# Trainable params: 913,091
# Non-trainable params: 0
# _________________________________________________________________

# %%
import time
nb_epoch = 1000
batch_size=100

model_name='test.chkpt'

if os.path.isfile(model_name):
    try:
        model = load_model(model_name)
        print('loading trained model ...')
    except Exception as e:
        print('Unable to load model', model_name, ':', e)
        raise    


adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
model.compile(optimizer=adam,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

startTime = time.time()
history = model.fit(X_train1, y_train1,
                    batch_size=batch_size, epochs=nb_epoch,
                    verbose=2, validation_data=(X_test1, y_test1))

endTime = time.time()
print('elapsed secs:', (endTime - startTime)/1000.)
#nvidia-smi to see power stats nvidia-smi -i 3 -l -q -d
# Out:
# Train on 6569 samples, validate on 1643 samples
# Epoch 1/1000
# 33s - loss: 1.0164 - acc: 0.5191 - val_loss: 0.9860 - val_acc: 0.5405
# Epoch 2/1000
# 35s - loss: 1.0049 - acc: 0.5264 - val_loss: 0.9780 - val_acc: 0.5405
# Epoch 3/1000
# 35s - loss: 0.9946 - acc: 0.5267 - val_loss: 0.9679 - val_acc: 0.5399
# Epoch 4/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-5954232307b7> in <module>()
#      22 history = model.fit(X_train1, y_train1,
#      23                     batch_size=batch_size, epochs=nb_epoch,
# ---> 24                     verbose=2, validation_data=(X_test1, y_test1))
#      25
#      26 endTime = time.time()
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#     854                               class_weight=class_weight,
#     855                               sample_weight=sample_weight,
# --> 856                               initial_epoch=initial_epoch)
#     857
#     858     def evaluate(self, x, y, batch_size=32, verbose=1,
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1496                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1497                               callback_metrics=callback_metrics,
# -> 1498                               initial_epoch=initial_epoch)
#    1499
#    1500     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1150                 batch_logs['size'] = len(batch_ids)
#    1151                 callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1152                 outs = f(ins_batch)
#    1153                 if not isinstance(outs, list):
#    1154                     outs = [outs]
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2227         session = get_session()
#    2228         updated = session.run(self.outputs + [self.updates_op],
# -> 2229                               feed_dict=feed_dict)
#    2230         return updated[:len(self.outputs)]
#    2231
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
loaded_model.summary()
# Out:
# Loaded model from disk
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 224, 224, 32)      896
# _________________________________________________________________
# relu1 (Activation)           (None, 224, 224, 32)      0
# _________________________________________________________________
# maxpool1 (MaxPooling2D)      (None, 223, 223, 32)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 223, 223, 64)      18496
# _________________________________________________________________
# relu2 (Activation)           (None, 223, 223, 64)      0
# _________________________________________________________________
# maxpool2 (MaxPooling2D)      (None, 111, 111, 64)      0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 111, 111, 128)     73856
# _________________________________________________________________
# relu3 (Activation)           (None, 111, 111, 128)     0
# _________________________________________________________________
# maxpool3 (MaxPooling2D)      (None, 55, 55, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 387200)            0
# _________________________________________________________________
# dropout1 (Dropout)           (None, 387200)            0
# _________________________________________________________________
# hidden1 (Dense)              (None, 128)               49561728
# _________________________________________________________________
# relu4 (Activation)           (None, 128)               0
# _________________________________________________________________
# dropout2 (Dropout)           (None, 128)               0
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# relu5 (Activation)           (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 3)                 387
# _________________________________________________________________
# softmax (Activation)         (None, 3)                 0
# =================================================================
# Total params: 49,671,875
# Trainable params: 49,671,875
# Non-trainable params: 0
# _________________________________________________________________

# %%
#this doesnt work to reset
from keras import backend as K

def limit_mem():
    K.get_session().close()
    cfg = K.tf.ConfigProto()
    cfg.gpu_options.allow_growth = True
    K.set_session(K.tf.Session(config=cfg))

limit_mem()

# %%
predict = loaded_model.predict(X_test)

# %%
predict[0]
# Out:
# array([  1.00749046e-13,   1.00000000e+00,   2.02010197e-11], dtype=float32)
