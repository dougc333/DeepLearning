# %%
#test debug
from IPython.core.debugger import set_trace

def foo():
    print("this is foo")
    a = 10
    set_trace()

# %%
foo()
# Out:
# this is foo
# --Return--
# None
# > <ipython-input-1-f3390f01f328>(7)foo()
#       3
#       4 def foo():
#       5     print("this is foo")
#       6     a = 10
# ----> 7     set_trace()
#
# ipdb> a
# ipdb> bt
#   /Users/dc/miniconda3/lib/python3.4/runpy.py(170)_run_module_as_main()
#     168         sys.argv[0] = mod_spec.origin
#     169     return _run_code(code, main_globals, None,
# --> 170                      "__main__", mod_spec)
#     171
#     172 def run_module(mod_name, init_globals=None,
#
#   /Users/dc/miniconda3/lib/python3.4/runpy.py(85)_run_code()
#      83                        __package__ = pkg_name,
#      84                        __spec__ = mod_spec)
# ---> 85     exec(code, run_globals)
#      86     return run_globals
#      87
#
#   /Users/dc/miniconda3/lib/python3.4/site-packages/ipykernel_launcher.py(16)<module>()
#      12     if sys.path[0] == '':
#      13         del sys.path[0]
#      14
#      15     from ipykernel import kernelapp as app
# ...
