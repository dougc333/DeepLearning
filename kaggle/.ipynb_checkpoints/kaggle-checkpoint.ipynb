# %%
# Load pickled data
import matplotlib.pyplot as plt
import pickle, cv2, csv, os, time
import numpy as np
from numpy import newaxis
from random import randint
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from matplotlib import gridspec
# %matplotlib inline

import copy
from keras.models import Sequential  #, Graph
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras.optimizers import SGD, RMSprop
from keras.utils import np_utils
from keras.regularizers import l2
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D, AveragePooling2D
from keras.callbacks import EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization

from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
import os
from skimage.transform import rescale, resize, downscale_local_mean


current_path = os.getcwd()
print (current_path)
train_path1 = current_path + "/train/Type_1/"
train_path2 = current_path + "/train/Type_2/"
train_path3 = current_path + "/train/Type_3/"
add_type1 = current_path + "/additional_Type_1_v2/Type_1/" 
add_type2 = current_path + "/additional_Type_2_v2/Type_2/" 
add_type3 = current_path + "/additional_Type_3_v2/Type_3/" 

test = current_path+"/test/"

path_list =[]
path_list.append(add_type1)
path_list.append(add_type2)
path_list.append(add_type3)
path_list.append(train_path1)
path_list.append(train_path2)
path_list.append(train_path3)

path_list.append(test)

resizeimg=[]
filename_resized=[]
   
def resize_images(path,pickle_filename):
    size_dict= {}
    #for path in path_list:
    start_time = time.time()
    for root, dirs, files in os.walk(path, topdown=False):
        print ("path:",path,' numFiles:',len(files))
        for f in files:
            if f !='.DS_Store':
                print ("path:",path," path+f:",path+f)
                img = cv2.imread(path+f)
                print ("img shape:",img.shape)
                image_resize = resize(img, (224, 224), mode='reflect')
                print("img_resize shape:",image_resize.shape)
                resizeimg.append(image_resize)
                print("size list:",len(resizeimg))
                filename_resized.append(f)
                size_dict[img.shape[0]]=img.shape[1]
        print("dict of image dimensions:",size_dict)
        with open(pickle_filename,'wb') as save_file:
            pickle.dump(resizeimg,save_file)
    end_time = time.time()
    print("elapsed time:",(end_time-start_time)/60.)

#uncomment each one to run. Should run wo memory error. 
#resize_images(train_path1,'type1_resize.p')
#resize_images(train_path2,'type2resize.p')
#resize_images(train_path3,'type3resize.p')
resize_images(add_type1,'type1addresize.p')
resize_images(add_type2,'type2addresize.p')
resize_images(add_type3,'type3add_resize.p')
resize_images(test,'test.p')
# Out:
# /Users/dc/DeepLearning/kaggle
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  numFiles: 1190
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/10.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 1
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1000.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 2
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1001.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 3
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1003.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1004.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 5
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1005.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 6
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1009.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 7
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1011.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 8
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/102.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 9
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1032.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 10
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1036.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 11
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/104.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 12
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1047.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 13
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1054.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 14
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1058.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 15
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1060.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 16
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1061.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 17
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1066.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 18
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1069.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 19
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1074.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 20
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1075.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 21
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1081.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 22
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1087.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 23
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1091.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 24
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1093.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 25
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1104.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 26
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/111.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 27
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1110.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 28
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1111.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 29
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1117.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 30
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1121.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 31
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1128.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 32
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1133.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 33
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1139.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 34
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1141.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 35
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1142.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 36
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1143.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 37
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/115.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 38
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/116.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 39
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1161.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 40
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1163.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 41
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1166.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 42
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1183.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 43
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1185.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 44
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/1189.jpg
# img shape: (640, 480, 3)
# img_resize shape: (224, 224, 3)
# size list: 45
# path: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_1_v2/Type_1/
jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 223
# ...
# size list: 4685
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/887.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4686
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/891.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4687
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/894.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4688
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/895.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 4689
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/896.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4690
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/897.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4691
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/898.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4692
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/9.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4693
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/90.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4694
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/900.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4695
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/901.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4696
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/902.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4697
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/903.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4698
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/904.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4699
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/906.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4700
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/908.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4701
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/91.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4702
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/912.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4703
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/913.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4704
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/915.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4705
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/916.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4706
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/917.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4707
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/919.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4708
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/92.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4709
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/920.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4710
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/921.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4711
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/922.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4712
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/923.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4713
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/929.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4714
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/93.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4715
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/930.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4716
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/932.jpg
# img shape: (4128, 2322, 3)
# img_resize shape: (224, 224, 3)
# size list: 4717
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/933.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4718
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/934.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4719
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/936.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4720
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/938.jpg
# img shape: (4160, 3120, 3)
# img_resize shape: (224, 224, 3)
# size list: 4721
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/939.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4722
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/94.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4723
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/940.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4724
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/941.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4725
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/944.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4726
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/946.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4727
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/947.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4728
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/948.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4729
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/950.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4730
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/951.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4731
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/952.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4732
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/953.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4733
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/955.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4734
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/956.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4735
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/96.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4736
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/960.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4737
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/961.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4738
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/962.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4739
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/963.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4740
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/969.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4741
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/971.jpg
# img shape: (4128, 2322, 3)
# img_resize shape: (224, 224, 3)
# size list: 4742
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/972.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4743
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/973.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4744
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/981.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4745
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/982.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4746
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/985.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4747
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/987.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4748
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/99.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4749
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/990.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4750
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/991.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4751
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/995.jpg
# img shape: (640, 480, 3)
# img_resize shape: (224, 224, 3)
# size list: 4752
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/997.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4753
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/998.jpg
# img shape: (3264, 2448, 3)
# img_resize shape: (224, 224, 3)
# size list: 4754
# path: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/  path+f: /Users/dc/DeepLearning/kaggle/additional_Type_2_v2/Type_2/999.jpg
# img shape: (4128, 3096, 3)
# img_resize shape: (224, 224, 3)
# size list: 4755
# dict of image dimensions: {4128: 3096, 3264: 2448, 2448: 3264, 3096: 4128, 4160: 3120, 640: 480}
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-740aac818d63> in <module>()
#      55 #resize_images(train_path3,'type3resize.p')
#      56 resize_images(add_type1,'type1addresize.p')
# ---> 57 resize_images(add_type2,'type2addresize.p')
#      58 resize_images(add_type3,'type3add_resize.p')
#      59 resize_images(test,'test.p')
#
# <ipython-input-12-740aac818d63> in resize_images(path, pickle_filename)
#      46         print("dict of image dimensions:",size_dict)
#      47         with open(pickle_filename,'wb') as save_file:
# ---> 48             pickle.dump(resizeimg,save_file)
#      49     end_time = time.time()
#      50     print("elapsed time:",(end_time-start_time)/60.)
#
# OSError: [Errno 22] Invalid argument

# %%
read_file = open('type1_resize.p', 'rb') 
imgs_type1 = pickle.load( read_file)
print("num type1 images(250):", len(imgs_type1)) #should be 250

read_file = open('type1add_resize.p', 'rb') 
imgs_type1add = pickle.load( read_file)
print('num type1 additional images(1190):',len(imgs_type1add))

read_file = open('type3resize.p', 'rb') 
imgs_type3 = pickle.load( read_file)
print('num type3 images(450):',len(imgs_type3)) 

read_file = open('type3add_resize.p', 'rb') 
imgs_type3add = pickle.load( read_file)
print('num type3 additional(1190):',len(imgs_type3add)) 

read_file = open('type2resize.p', 'rb') 
imgs_type2 = pickle.load( read_file)
print('num type2 images(781):',len(imgs_type2)) 

read_file = open('type2addresize.p', 'rb') 
imgs_type2add = pickle.load( read_file)
print('num type2 additional(1190):',len(imgs_type2add))
# Out:
# num type1 images(250): 250
# num type1 additional images(1190): 1190
# num type3 images(450): 450
# num type3 additional(1190): 1190
# num type2 images(781): 781
# num type2 additional(1190): 1190

# %%
import scipy.ndimage as ndi

#crop test
img = cv2.imread('/Users/dc/DeepLearning/kaggle/train/Type_1/0.jpg')

height = img.shape[0]
width = img.shape[1]
cv2.line(img,(0,int(height/2.)),(int(width),int(height/2.0)),(255,0,0))
cv2.line(img,(int(width/2.),0),(int(width/2.0),height),(255,0,0))

trans_factor=.8 
zoom_range=[.8,.8]


y_offset = np.random.uniform(0,trans_factor*width)
x_offset = np.random.uniform(0,trans_factor*height)

print ('y_offset:', y_offset, "x_offset:", x_offset)

offset = np.array([0,200])
#center image
#offset=np.array([10,10])
scale_factor = np.random.uniform(zoom_range[0],zoom_range[1])
print (scale_factor)
crop = np.array([[scale_factor,0],[0,scale_factor]])

print('image.shape before roll:',img.shape)
img_roll = np.rollaxis(img,axis=-1, start=0)
print('image.shape after roll:',img_roll.shape)
#this is for the affine transform for each channel you have to roll the axis? Seems funky
#you can use a numpy.reshape also. this is clearer and more mainstream

image_channel = [ndi.interpolation.affine_transform(image_channel,
                        crop, offset=offset, order=0, mode='nearest',
                        cval=0.0) for image_channel in img_roll]
image_array = np.stack(image_channel, axis=0)
image_array = np.rollaxis(image_array, 0, 3)

print ('image_array:',image_array.shape)
#height_rs = image_array.shape[0]
#width_rs = image_array.shape[1]
#print(height_rs, width_rs)
#cv2.line(image_array,(10,10),(100,100),(255,0,0))
#cv2.line(image_array,(0,int(height_rs/2.)),(int(width_rs),int(height_rs/2.0)),(255,0,0))
#cv2.line(image_array,(int(width_rs/2.),0),(int(width_rs/2.0),height_rs),(255,0,0))

fig = plt.figure()

ax = fig.add_subplot(2, 2, 1)
ax.imshow(img)
plt.title("orig")
ax1 = fig.add_subplot(2, 2, 2)
ax1.imshow(image_array)
plt.title("crop .8")
#fig.add_subplot(image_array)

#plt.show()
#problem is the shift away from center in the crop .8 image

# %%
#we can crop to produce a smaller resolution. 
import skimage
from skimage.transform import rescale, resize, downscale_local_mean

image = cv2.imread('/Users/dc/DeepLearning/kaggle/train/Type_1/0.jpg')
height = image.shape[0]
width = image.shape[1]
cv2.line(image,(0,int(height/2.)),(int(width),int(height/2.0)),(255,0,0))
cv2.line(image,(int(width/2.),0),(int(width/2.0),height),(255,0,0))


print ('orig:',image.shape)
image_resized = resize(image, (400, 400), mode='reflect')
height = image_resized.shape[0]
width = image_resized.shape[1]
cv2.line(image_resized,(0,int(height/2.)),(int(width),int(height/2.0)),(255,0,0))
cv2.line(image_resized,(int(width/2.),0),(int(width/2.0),height),(255,0,0))

#image_downscaled = downscale_local_mean(image, (480, 640))
print ('resized:',image_resized.shape)
fig, axes = plt.subplots(nrows=2, ncols=2,
                         sharex=True, sharey=True)

ax = axes.ravel()
ax[0].imshow(image)
ax[0].set_title("Original image")

ax[1].imshow(image_resized)
ax[1].set_title("resized")

#ax[2].imshow(image_downscaled)
#ax[2].set_title("downscaled")
# Out:
# orig: (3264, 2448, 3)
# resized: (400, 400, 3)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator







print (K.image_data_format())

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=( 150, 150,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))
# Out:
# channels_last

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
import os,random


def move_file(source_path,dest_path):
    """
    input: source path, dest path
    output: move 20 percent files from source path to dest path
    """
    list_files = os.listdir(source_path)
    print (len(list_files))

    num_moved=0
    for x in range(1,int(.20*len(list_files))):
        index = random.randint(1, len(list_files))
        print(index,list_files[index])
        source_file = source_path+list_files[index]
        if(os.path.isfile(source_file)):
            dest_file = dest_path+list_files[index]
            os.rename(source_file,dest_file)
            num_moved+=1

    print (num_moved)

move_file(os.getcwd()+"/data/train/type1/",os.getcwd()+"/data/valid/type1/")
# Out:
# 1393
# 20 104.jpg
# 589 3207.jpg
# 1055 5985.jpg
# 1127 623.jpg
# 477 2729.jpg
# 529 2951.jpg
# 1058 5988.jpg
# 481 2737.jpg
# 124 132.jpg
# 570 3095.jpg
# 1361 921.jpg
# 529 2951.jpg
# 173 1452.jpg
# 827 4323.jpg
# 1289 720.jpg
# 12 102.jpg
# 182 1474.jpg
# 1090 608.jpg
# 896 4724.jpg
# 348 2187.jpg
# 884 47.jpg
# 691 3705.jpg
# 448 2590.jpg
# 154 1404.jpg
# 1132 625.jpg
# 20 104.jpg
# 1207 6527.jpg
# 1185 6445.jpg
# 1249 6757.jpg
# 119 1307.jpg
# 303 2009.jpg
# 216 1612.jpg
# 937 501.jpg
# 530 2954.jpg
# 799 4032.jpg
# 1102 6106.jpg
# 75 1197.jpg
# 839 444.jpg
# 1119 6188.jpg
# 527 294.jpg
# 226 1666.jpg
# 1303 75.jpg
# 755 396.jpg
# 511 2862.jpg
# 1221 6594.jpg
# 1240 6685.jpg
# 299 1995.jpg
# 1374 965.jpg
# 856 4555.jpg
# 486 2763.jpg
# 676 3659.jpg
# 632 3441.jpg
# 1198 6500.jpg
# 275 1832.jpg
# 993 576.jpg
# 638 3458.jpg
# 864 463.jpg
# 1021 5846.jpg
# 340 2161.jpg
# 776 40.jpg
# 1380 975.jpg
# 743 3886.jpg
# 1214 6547.jpg
# 1013 5809.jpg
# 759 3974.jpg
# 962 534.jpg
# 482 2738.jpg
# 178 1466.jpg
# 402 2410.jpg
# 910 481.jpg
# 1303 75.jpg
# 462 2659.jpg
# 496 2810.jpg
# 598 3258.jpg
# 924 4905.jpg
# 27 1060.jpg
# 969 5360.jpg
# 710 3795.jpg
# 1329 836.jpg
# 517 2883.jpg
# 886 4701.jpg
# 1247 6750.jpg
# 202 1547.jpg
# 317 2054.jpg
# 277 1863.jpg
# 973 5406.jpg
# 1037 5913.jpg
# 695 3727.jpg
# 871 4684.jpg
# 920 4889.jpg
# 1367 942.jpg
# 133 134.jpg
# 561 3068.jpg
# 233 1707.jpg
# 1326 821.jpg
# 1367 942.jpg
# 697 3740.jpg
# 225 1661.jpg
# 273 1828.jpg
# 885 470.jpg
# 914 4874.jpg
# 688 3694.jpg
# 844 4510.jpg
# 837 440.jpg
# 1144 6360.jpg
# 443 2569.jpg
# 399 2398.jpg
# 1109 6139.jpg
# 132 1339.jpg
# 568 3087.jpg
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# this is a generator that will read pictures found in
# subfolers of 'data/train', and indefinitely generate
# batches of augmented image data
train_generator = train_datagen.flow_from_directory(
        'data/train',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
        'data/valid',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.

# %%
type(train_datagen)
# Out:
# keras.preprocessing.image.ImageDataGenerator

# %%
model.fit_generator(
        train_generator,
        steps_per_epoch=2000 // batch_size,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=800 // batch_size)
model.save_weights('first_try.h5')
# Out:
# Epoch 1/50
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/dc/anaconda/envs/py35/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/Users/dc/anaconda/envs/py35/lib/python3.5/threading.py", line 862, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/engine/training.py", line 612, in data_generator_task
#     generator_output = next(self._generator)
#   File "/Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/preprocessing/image.py", line 727, in __next__
#     return self.next(*args, **kwargs)
#   File "/Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/preprocessing/image.py", line 950, in next
#     index_array, current_index, current_batch_size = next(self.index_generator)
#   File "/Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/preprocessing/image.py", line 710, in _flow_index
#     current_index = (self.batch_index * batch_size) % n
# ZeroDivisionError: integer division or modulo by zero
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ec6d1179848c> in <module>()
#       4         epochs=50,
#       5         validation_data=validation_generator,
# ----> 6         validation_steps=800 // batch_size)
#       7 model.save_weights('first_try.h5')
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/models.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1108                                         workers=workers,
#    1109                                         pickle_safe=pickle_safe,
# -> 1110                                         initial_epoch=initial_epoch)
#    1111
#    1112     @interfaces.legacy_generator_methods_support
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      86                 warnings.warn('Update your `' + object_name +
#      87                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 88             return func(*args, **kwargs)
#      89         wrapper._legacy_support_signature = inspect.getargspec(func)
#      90         return wrapper
#
# /Users/dc/anaconda/envs/py35/lib/python3.5/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_q_size, workers, pickle_safe, initial_epoch)
#    1863                                          'a tuple `(x, y, sample_weight)` '
#    1864                                          'or `(x, y)`. Found: ' +
# -> 1865                                          str(generator_output))
#    1866                     if len(generator_output) == 2:
#    1867                         x, y = generator_output
#
# ValueError: output of generator should be a tuple `(x, y, sample_weight)` or `(x, y)`. Found: None
